# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavi1thoom/road-Damage-CNN-/blob/main/RoadDamage(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# pip install kagglehub[pandas-datasets]
# pip install kagglehub

import kagglehub

path = kagglehub.dataset_download(
    "lorenzoarcioni/road-damage-dataset-potholes-cracks-and-manholes"
)

print("Dataset downloaded to:", path)
# Out:
# Using Colab cache for faster access to the 'road-damage-dataset-potholes-cracks-and-manholes' dataset.
# Dataset downloaded to: /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes
# Using Colab cache for faster access to the 'road-damage-dataset-potholes-cracks-and-manholes' dataset.
# Dataset downloaded to: /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
dataset_path = "/kaggle/input/road-damage-dataset-potholes-cracks-and-manholes"

# %%
for root, dirs, files in os.walk(dataset_path):
    print(root)
# Out:
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/labels
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/images
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/labels-YOLO

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Image Resizing + Normalization + Split

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %% [markdown]
# Training data

# %%
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 1608 images belonging to 1 classes.

# %% [markdown]
# Testing Data

# %%
test_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 401 images belonging to 1 classes.

# %% [markdown]
# Label Encoding

# %%
print(train_data.class_indices)
# Out:
# {'data': 0}

# %% [markdown]
# Data Augmentation

# %%
augmented_data = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8,1.2],
    validation_split=0.2
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

model = Sequential()

model.add(Conv2D(
    32,(3,3),
    activation='relu',
    input_shape=(224,224,3)
))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(256,activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(
    train_data.num_classes,
    activation='softmax'
))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# model compile

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# model evaluation

# %%
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=20
)
# Out:
# Epoch 1/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 35s 689ms/step - accuracy: 0.4981 - loss: 1.0474 - val_accuracy: 0.4988 - val_loss: 1.0457
# Epoch 2/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 34s 661ms/step - accuracy: 0.4975 - loss: 1.0314 - val_accuracy: 0.4988 - val_loss: 1.0476
# Epoch 3/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 635ms/step - accuracy: 0.4994 - loss: 1.0230 - val_accuracy: 0.4988 - val_loss: 1.1337
# Epoch 4/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 33s 655ms/step - accuracy: 0.5075 - loss: 1.0065 - val_accuracy: 0.4963 - val_loss: 1.1218
# Epoch 5/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 637ms/step - accuracy: 0.4988 - loss: 1.0062 - val_accuracy: 0.4988 - val_loss: 1.1170
# Epoch 6/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 33s 650ms/step - accuracy: 0.4907 - loss: 1.0076 - val_accuracy: 0.4988 - val_loss: 1.0927
# Epoch 7/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 638ms/step - accuracy: 0.5012 - loss: 0.9851 - val_accuracy: 0.4988 - val_loss: 1.2235
# Epoch 8/20
# ...

# %%
loss, accuracy = model.evaluate(test_data)

print("Accuracy:", accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 543ms/step - accuracy: 0.4863 - loss: 1.3747
# Accuracy: 0.4862842857837677

# %% [markdown]
# precision,recall,F1-Score

# %%
from sklearn.metrics import classification_report
import numpy as np

predictions = model.predict(test_data)

y_pred = np.argmax(predictions, axis=1)

print(classification_report(
    test_data.classes,
    y_pred
))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       401
#
#     accuracy                           1.00       401
#    macro avg       1.00      1.00      1.00       401
# weighted avg       1.00      1.00      1.00       401

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(
    test_data.classes,
    y_pred
)

plt.figure(figsize=(8,6))

sns.heatmap(cm, annot=True, fmt='d')

plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %% [markdown]
# Error Analysis

# %%
wrong = np.where(
    y_pred != test_data.classes
)[0]

print("Wrong Predictions:", len(wrong))
# Out:
# Wrong Predictions: 0

# %% [markdown]
# real-time prediction

# %%
from tensorflow.keras.preprocessing import image

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce2699c5-0998-4457-bea9-603cee916c21" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce2699c5-0998-4457-bea9-603cee916c21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img_path = "road.jpg"

img = image.load_img(
    img_path,
    target_size=(224,224)
)

img_array = image.img_to_array(img)

img_array = img_array/255.0

img_array = np.expand_dims(
    img_array,
    axis=0
)

prediction = model.predict(img_array)

predicted_class = np.argmax(prediction)

labels = list(train_data.class_indices.keys())

print("Prediction:",
      labels[predicted_class])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step
# Prediction: data

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-92dbd764-c3f0-473b-b160-1bce5a30e352" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92dbd764-c3f0-473b-b160-1bce5a30e352">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "road1.jpg"

img = image.load_img(
    img_path,
    target_size=(224,224)
)

img_array = image.img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(
    img_array,
    axis=0
)

prediction = model.predict(img_array)

predicted_class = np.argmax(prediction)

labels = list(train_data.class_indices.keys())

print("Prediction:",
      labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# Prediction: crack

# %%
import os

dataset_path = "/kaggle/input/road-damage-dataset-potholes-cracks-and-manholes"

for root, dirs, files in os.walk(dataset_path):
    print(root)
# Out:
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/labels
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/images
# /kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/labels-YOLO

# %%
import os

label_path = "/kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/labels-YOLO"

files = os.listdir(label_path)

print(files[:5])
# Out:
# ['vlcsnap-2025-02-19-14h18m48s452.txt', 'vlcsnap-2025-02-19-14h21m29s062.txt', 'vlcsnap_2025-03-16-15h14m35s770.txt', 'vlcsnap-2025-02-18-23h25m45s670.txt', 'vlcsnap-2025-02-19-17h09m41s152.txt']

# %%
import os

label_path = "/kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/labels-YOLO"

sample_file = os.path.join(
    label_path,
    "vlcsnap-2025-02-19-14h18m48s452.txt"
)

with open(sample_file, "r") as f:
    print(f.read())
# Out:
# 2 0.372656 0.575000 0.060938 0.033334
# 2 0.431250 0.577778 0.043750 0.033333

# %%
class_names = {
    0: "pothole",
    1: "crack",
    2: "manhole"
}

# %%
import os

new_dataset = "/kaggle/working/road_classification"

os.makedirs(new_dataset, exist_ok=True)

for class_name in class_names.values():
    os.makedirs(
        os.path.join(new_dataset, class_name),
        exist_ok=True
    )

print("Folders Created")
# Out:
# Folders Created

# %%
import shutil

image_path = "/kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/images"

label_path = "/kaggle/input/road-damage-dataset-potholes-cracks-and-manholes/data/labels-YOLO"

for label_file in os.listdir(label_path):

    if not label_file.endswith(".txt"):
        continue

    txt_path = os.path.join(label_path, label_file)

    with open(txt_path, "r") as f:
        lines = f.readlines()

    if len(lines) == 0:
        continue

    # Take first object class
    class_id = int(lines[0].split()[0])

    class_name = class_names[class_id]

    image_file = label_file.replace(".txt", ".jpg")

    src_image = os.path.join(image_path, image_file)

    dst_image = os.path.join(
        new_dataset,
        class_name,
        image_file
    )

    if os.path.exists(src_image):
        shutil.copy(src_image, dst_image)

print("Dataset Converted Successfully")
# Out:
# Dataset Converted Successfully

# %%
for root, dirs, files in os.walk(new_dataset):
    print(root, len(files))
# Out:
# /kaggle/working/road_classification 0
# /kaggle/working/road_classification/crack 1002
# /kaggle/working/road_classification/pothole 466
# /kaggle/working/road_classification/manhole 541

# %%
dataset_path = "/kaggle/working/road_classification"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8,1.2],
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

test_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 1608 images belonging to 3 classes.
# Found 401 images belonging to 3 classes.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-386ee249-7e0e-4330-9e5a-685f7248514f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-386ee249-7e0e-4330-9e5a-685f7248514f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "road.jpg"

img = image.load_img(
    img_path,
    target_size=(224,224)
)

img_array = image.img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(
    img_array,
    axis=0
)

prediction = model.predict(img_array)

predicted_class = np.argmax(prediction)

labels = list(train_data.class_indices.keys())

print("Prediction:",
      labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Prediction: crack

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c87a22f-15ee-46ad-805f-485a4ffba648" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c87a22f-15ee-46ad-805f-485a4ffba648">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "road2.jpg"

img = image.load_img(
    img_path,
    target_size=(224,224)
)

img_array = image.img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(
    img_array,
    axis=0
)

prediction = model.predict(img_array)

predicted_class = np.argmax(prediction)

labels = list(train_data.class_indices.keys())

print("Prediction:",
      labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Prediction: crack

# %%
import os

dataset_path = "/kaggle/working/road_classification"

for folder in os.listdir(dataset_path):

    folder_path = os.path.join(dataset_path, folder)

    count = len(os.listdir(folder_path))

    print(folder, ":", count)
# Out:
# crack : 1002
# pothole : 466
# manhole : 541

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-713e5d81-9de0-4765-a8be-a0735c6d042d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-713e5d81-9de0-4765-a8be-a0735c6d042d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "road3.jpg"

img = image.load_img(
    img_path,
    target_size=(224,224)
)

img_array = image.img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(
    img_array,
    axis=0
)

prediction = model.predict(img_array)

predicted_class = np.argmax(prediction)

labels = list(train_data.class_indices.keys())

print("Prediction:",
      labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Prediction: manhole

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "road2.jpg"

img = image.load_img(
    img_path,
    target_size=(224,224)
)

img_array = image.img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(
    img_array,
    axis=0
)

prediction = model.predict(img_array)

predicted_class = np.argmax(prediction)

labels = list(train_data.class_indices.keys())

print("Prediction:",
      labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Prediction: crack

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2280b108-62b4-4c65-a6d8-a5a5ba840f75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2280b108-62b4-4c65-a6d8-a5a5ba840f75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "road5.jpg"

img = image.load_img(
    img_path,
    target_size=(224,224)
)

img_array = image.img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(
    img_array,
    axis=0
)

prediction = model.predict(img_array)

predicted_class = np.argmax(prediction)

labels = list(train_data.class_indices.keys())

print("Prediction:",
      labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Prediction: crack
